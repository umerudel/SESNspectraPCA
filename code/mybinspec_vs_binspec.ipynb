# %%
from __future__ import print_function

import numpy as np
import matplotlib.pyplot as plt
from BinSpectra import mybinspec
from SNIDsn import binspec
from TestBin import compare_binspec


import SNIDsn
import SNIDdataset as snid
import SNePCA
import plotly.plotly as ply
import plotly.graph_objs as go
import plotly.tools as tls
import pandas
import scipy

# %%
dataset15 = snid.loadPickle('../Data/DataProducts/dataset15.pickle')
wvl = dataset15["sn2006el"].wavelengths
flux_0 = dataset15["sn2006el"].data
flux = flux_0.astype('float64')
#textstr = 'SNe: %.2f\nBinning length = %.2f\n'%(1, 2)
sn_name = 'sn2006el'

# %%
f = compare_binspec(wvl, flux, 30, sn_name)

# %%
dataset15 = snid.loadPickle('../Data/DataProducts/dataset15.pickle')
wvl = dataset15["sn2013dx"].wavelengths
flux_0 = dataset15["sn2013dx"].data
flux = flux_0.astype('float64')
textstr = 'sn2013dx, Bin length = 40'

# %%
f = compare_binspec(wvl, flux, 40, textstr)

# %%
dataset15 = snid.loadPickle('../Data/DataProducts/dataset15.pickle')
wvl = dataset15["sn2013dx"].wavelengths
flux_0 = dataset15["sn2013dx"].data
flux = flux_0.astype('float64')
uncer = dataset15["sn2013dx"].smooth_uncertainty["Ph13.4"]
plt.errorbar(wvl, flux, c='xkcd:red',yerr=uncer)
# Out:
# <ErrorbarContainer object of 3 artists>
