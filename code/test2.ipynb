# %%
import numpy as np
import matplotlib.pyplot as plt
from TestBin import testbin

# %% [markdown]
# # Testing sample spectrums with a drop at EDGES

# %% [markdown]
# ## Spectrum array length: 10
# ## Right drop length: 3
# ## Left drop length: 3
# ## Binning factor: 3.0

# %%
wvl = np.exp(np.arange(1., 3., 0.2))
flux = np.ones(len(wvl))
testbin(wvl, flux, 3.0, 3, 3)

# %% [markdown]
# ## Spectrum array length: 14
# ## Right drop length: 5
# ## Left drop length: 4
# ## Binning factor: 2.5

# %%
wvl = np.exp(np.arange(1., 3., 0.15))
flux = np.ones(len(wvl))
testbin(wvl, flux, 2.5, 4, 5)

# %% [markdown]
# ## Spectrum array length: 14
# ## Right drop length: 5
# ## Left drop length: 4
# ## Binning factor: 1.5

# %%
wvl = np.exp(np.arange(1., 3., 0.15))
flux = np.ones(len(wvl))
testbin(wvl, flux, 1.5, 4, 5)

# %% [markdown]
# ## Spectrum array length: 14
# ## Right drop length: 5
# ## Left drop length: 4
# ## Binning factor: 14.0

# %%
wvl = np.exp(np.arange(1., 3., 0.15))
flux = np.ones(len(wvl))
testbin(wvl, flux, 14.0, 4, 5)

# %% [markdown]
# ## Spectrum array length: 7
# ## Right drop length: 2
# ## Left drop length: 2
# ## Binning factor: 3.3

# %%
wvl = np.exp(np.arange(1., 3., 0.3))
flux = np.ones(len(wvl))
testbin(wvl, flux, 3.3, 2, 2)

# %% [markdown]
# ## Spectrum array length: 9
# ## Right drop length: 2
# ## Left drop length: 3
# ## Binning factor: 3.0

# %%
wvl = np.exp(np.arange(1., 3., 0.23))
flux = np.ones(len(wvl))
testbin(wvl, flux, 3.0, 2, 3)
