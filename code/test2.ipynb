# %%
import numpy as np
import matplotlib.pyplot as plt
from BinSpectra import binspec
from TestBin import testbin

# %% [markdown]
# # Testing sample spectrums with a drop at left and right

# %% [markdown]
# ## Spectrum array length: 10
# ## Right drop length: 3
# ## Left drop length: 3
# ## Binning factor: 3.0

# %%
wvl = np.exp(np.arange(1., 3., 0.2))
flux = np.ones(len(wvl))
testbin(wvl, flux, 3.0, 3, 3)
# Out:
# No. of new bins should be: 3 ;  No. of new bins are: (3,)

# %% [markdown]
# ## Spectrum array length: 14
# ## Right drop length: 5
# ## Left drop length: 4
# ## Binning factor: 2.5

# %%
wvl = np.exp(np.arange(1., 3., 0.15))
flux = np.ones(len(wvl))
testbin(wvl, flux, 2.5, 4, 5)
# Out:
# No. of new bins should be: 5 ;  No. of new bins are: (5,)

# %% [markdown]
# ## Spectrum array length: 14
# ## Right drop length: 5
# ## Left drop length: 4
# ## Binning factor: 1.0

# %%
wvl = np.exp(np.arange(1., 3., 0.15))
flux = np.ones(len(wvl))
testbin(wvl, flux, 1.0, 4, 5)
# Out:
# No. of new bins should be: 14 ;  No. of new bins are: (14,)

# %% [markdown]
# ## Spectrum array length: 14
# ## Right drop length: 5
# ## Left drop length: 4
# ## Binning factor: 14.0

# %%
wvl = np.exp(np.arange(1., 3., 0.15))
flux = np.ones(len(wvl))
testbin(wvl, flux, 14.0, 4, 5)
# Out:
# No. of new bins should be: 1 ;  No. of new bins are: (1,)

# %% [markdown]
# ## Spectrum array length: 7
# ## Right drop length: 2
# ## Left drop length: 2
# ## Binning factor: 3.3

# %%
wvl = np.exp(np.arange(1., 3., 0.3))
flux = np.ones(len(wvl))
testbin(wvl, flux, 3.3, 2, 2)
# Out:
# No. of new bins should be: 2 ;  No. of new bins are: (2,)

# %% [markdown]
# ## Spectrum array length: 9
# ## Right drop length: 2
# ## Left drop length: 3
# ## Binning factor: 3.0

# %%
wvl = np.exp(np.arange(1., 3., 0.23))
flux = np.ones(len(wvl))
testbin(wvl, flux, 3.0, 2, 3)
# Out:
# No. of new bins should be: 3 ;  No. of new bins are: (3,)
