# %%
import SNIDsn
import SNIDdataset as snid
import numpy as np
import SNePCA

import plotly.plotly as ply
import plotly.graph_objs as go
import plotly.tools as tls

import matplotlib.pyplot as plt

# %%
dataset0 = snid.loadDataset(pathdir='allSNIDtemp/', snlist='snlist.txt')
dataset5 = snid.loadDataset(pathdir='allSNIDtemp/', snlist='snlist.txt')
dataset10 = snid.loadDataset(pathdir='allSNIDtemp/', snlist='snlist.txt')
dataset15 = snid.loadDataset(pathdir='allSNIDtemp/', snlist='snlist.txt')

#dataset0 = snid.loadDataset(pathdir='/home/data/mew488/Desktop/NYU/Research/SNID/', snlist='/home/data/mew488/Desktop/NYU/Research/sn.txt')
#dataset5 = snid.loadDataset(pathdir='/home/data/mew488/Desktop/NYU/Research/SNID/', snlist='/home/data/mew488/Desktop/NYU/Research/sn.txt')
#dataset10 = snid.loadDataset(pathdir='/home/data/mew488/Desktop/NYU/Research/SNID/', snlist='/home/data/mew488/Desktop/NYU/Research/sn.txt')
#dataset15 = snid.loadDataset(pathdir='/home/data/mew488/Desktop/NYU/Research/SNID/', snlist='/home/data/mew488/Desktop/NYU/Research/sn.txt')

#dataset20 = snid.loadDataset(pathdir='allSNIDtemp/', snlist='snlist.txt')
#dataset25 = snid.loadDataset(pathdir='allSNIDtemp/', snlist='snlist.txt')
# Out:
# sn00cn_bsnip.lnw
#
# sn00cp_bsnip.lnw
#
# sn00cu_bsnip.lnw
#
# sn00cw_bsnip.lnw
#
# sn00dg_bsnip.lnw
#
# sn00dk_bsnip.lnw
#
# sn00dm_bsnip.lnw
#
# sn00dn_bsnip.lnw
#
# sn00ev_bsnip.lnw
#
# sn00fa_bsnip.lnw
#
# sn00fe_bsnip.lnw
#
# sn01ad_bsnip.lnw
#
# sn01bg_bsnip.lnw
#
# sn01cm_bsnip.lnw
#
# sn01cy_bsnip.lnw
#
# sn01dk_bsnip.lnw
#
# sn01do_bsnip.lnw
#
# sn01dw_bsnip.lnw
#
# sn01ef_bsnip.lnw
#
# sn01eh_bsnip.lnw
#
# sn01en_bsnip.lnw
#
# sn01ep_bsnip.lnw
#
# sn01ey_bsnip.lnw
#
# sn01gd_bsnip.lnw
#
# sn01hg_bsnip.lnw
#
# sn01ir_bsnip.lnw
#
# sn01K_bsnip.lnw
#
# sn01M_bsnip.lnw
#
# sn01X_bsnip.lnw
#
# sn02A_bsnip.lnw
#
# sn02an_bsnip.lnw
#
# sn02ap_bsnip.lnw
#
# sn02bg_bsnip.lnw
#
# sn02bo_bsnip.lnw
#
# sn02bu_bsnip.lnw
#
# sn02bx_bsnip.lnw
#
# sn02bz_bsnip.lnw
#
# sn02ca_bsnip.lnw
#
# sn02cf_bsnip.lnw
#
# sn02cr_bsnip.lnw
#
# sn02cs_bsnip.lnw
#
# sn02dq_bsnip.lnw
#
# sn02ef_bsnip.lnw
#
# sn02eg_bsnip.lnw
#
# sn02ei_bsnip.lnw
#
# sn02el_bsnip.lnw
#
# sn02eo_bsnip.lnw
#
# ...

# %%
typeinfo = snid.datasetTypeDict(dataset0)
sesn = np.concatenate((typeinfo['Ib'], typeinfo['IIb'], typeinfo['Ic'], typeinfo['IcBL']))
dataset0 = snid.subset(dataset0, sesn)

typeinfo = snid.datasetTypeDict(dataset5)
sesn = np.concatenate((typeinfo['Ib'], typeinfo['IIb'], typeinfo['Ic'], typeinfo['IcBL']))
dataset5 = snid.subset(dataset5, sesn)

typeinfo = snid.datasetTypeDict(dataset10)
sesn = np.concatenate((typeinfo['Ib'], typeinfo['IIb'], typeinfo['Ic'], typeinfo['IcBL']))
dataset10 = snid.subset(dataset10, sesn)

typeinfo = snid.datasetTypeDict(dataset15)
sesn = np.concatenate((typeinfo['Ib'], typeinfo['IIb'], typeinfo['Ic'], typeinfo['IcBL']))
dataset15 = snid.subset(dataset15, sesn)




#typeinfo = snid.datasetTypeDict(dataset20)
#sesn = np.concatenate((typeinfo['Ib'], typeinfo['IIb'], typeinfo['Ic'], typeinfo['IcBL']))
#dataset20 = snid.subset(dataset20, sesn)

#typeinfo = snid.datasetTypeDict(dataset25)
#sesn = np.concatenate((typeinfo['Ib'], typeinfo['IIb'], typeinfo['Ic'], typeinfo['IcBL']))
#dataset25 = snid.subset(dataset25, sesn)

# %%
snid.snidsetNAN(dataset0)
snid.snidsetNAN(dataset5)
snid.snidsetNAN(dataset10)
snid.snidsetNAN(dataset15)

#snid.snidsetNAN(dataset20)
#snid.snidsetNAN(dataset25)

# %%
snid.interpGaps(dataset0, 4000, 7000, 20)
snid.interpGaps(dataset5, 4000, 7000, 20)
snid.interpGaps(dataset10, 4000, 7000, 20)
snid.interpGaps(dataset15, 4000, 7000, 20)

#snid.interpGaps(dataset20, 4000, 7000, 20)
#snid.interpGaps(dataset25, 4000, 7000, 20)

# %%
snid.datasetWavelengthRange(dataset0, 4000, 7000)
snid.datasetWavelengthRange(dataset5, 4000, 7000)
snid.datasetWavelengthRange(dataset10, 4000, 7000)
snid.datasetWavelengthRange(dataset15, 4000, 7000)

#snid.datasetWavelengthRange(dataset20, 4000, 7000)
#snid.datasetWavelengthRange(dataset25, 4000, 7000)

# %%
snid.smoothSpectra(dataset0, velcut=1000, velcutIcBL=3000, plot=False)
snid.smoothSpectra(dataset5, velcut=1000, velcutIcBL=3000, plot=False)
snid.smoothSpectra(dataset10, velcut=1000, velcutIcBL=3000, plot=False)
snid.smoothSpectra(dataset15, velcut=1000, velcutIcBL=3000, plot=False)

#snid.smoothSpectra(dataset20, velcut=1000, velcutIcBL=3000, plot=False)
#snid.smoothSpectra(dataset25, velcut=1000, velcutIcBL=3000, plot=False)

# %%
snid.filterPhases(dataset0, [(-5,5)], False)
snid.filterPhases(dataset5, [(0,10)], False)
snid.filterPhases(dataset10, [(5,15)], False)
snid.filterPhases(dataset15, [(10,20)], False)

#snid.filterPhases(dataset20, [(15,25)], False)
#snid.filterPhases(dataset25, [(20,30)], False)
# Out:
# /home/data/mew488/src/SNIDdataset/SNIDdataset.py:176: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
len(dataset0.keys())
# Out:
# 86

# %%
d = dataset15
typeinfo = snid.datasetTypeDict(d)
phaseinfo = snid.datasetPhaseDict(d)

# %%
print "N SNe"
print "Ib = ", len(typeinfo['Ib'])
print "IIb = ", len(typeinfo['IIb'])
print "Ic = ", len(typeinfo['Ic'])
print "IcBL = ", len(typeinfo['IcBL'])
# Out:
# N SNe
# Ib =  22
# IIb =  14
# Ic =  15
# IcBL =  12

# %%
for tp in ['Ib', 'IIb', 'Ic', 'IcBL']:
    dd=snid.subset(d,typeinfo[tp])
    p=snid.datasetPhaseDict(dd)
    count =0
    for k in p.keys():
        #print k
        count = count + len(p[k])
    print tp, count
# Out:
# Ib 58
# IIb 32
# Ic 35
# IcBL 29

# %%
dd=snid.subset()

# %%
dd=snid.subset

# %%
phaseinfo
# Out:
# {'sn04aw_bsnip': array([-3.3, -2.2, -1.7, -1.3, -0.2,  0.8,  1.6,  1.9,  2.6,  3.1,  3.6]),
#  'sn1988L': array([0.]),
#  'sn1990aa': array([0.]),
#  'sn1991A': array([0.]),
#  'sn1991N': array([0.]),
#  'sn1993J': array([-4. , -3. , -2.4, -2. , -1.6,  1.4,  2.7,  3.4,  3.7,  3.8,  4.6]),
#  'sn1994I': array([-4.94, -3.94, -2.94, -2.94, -1.94, -0.94,  1.06,  2.06,  2.06,
#          3.06,  3.06]),
#  'sn1995F': array([0.2, 1.9, 4. ]),
#  'sn1996cb': array([-3.9, -0.9,  3.1,  4.1]),
#  'sn1997X': array([0., 2.]),
#  'sn1997dc': array([0.]),
#  'sn1997dd': array([0. , 3.6]),
#  'sn1997dq': array([0., 1.]),
#  'sn1997ef': array([-4.1]),
#  'sn1998bw': array([-4.2, -3.2, -1.2,  0.8,  1.8,  3.8]),
#  'sn1998dt': array([1.8, 2.8]),
#  'sn1998fa': array([-4.1, -3.1]),
#  'sn1999di': array([0.]),
#  'sn1999dn': array([-1.,  0.,  3.]),
#  'sn1999ec': array([0.]),
#  'sn1999ex': array([-4.5,  0.4]),
#  'sn2000H': array([-1.8, -0.8, -0.1,  1.1,  2.1,  3.1,  4.9]),
#  'sn2001ai': array([0.]),
# ...

# %%
snid.filterPhases(dataset0, [(-5,5)], True)
snid.filterPhases(dataset5, [(0,10)], True)
snid.filterPhases(dataset10, [(5,15)], True)
snid.filterPhases(dataset15, [(10,20)], True)

#snid.filterPhases(dataset20, [(15,25)], True)
#nid.filterPhases(dataset25, [(20,30)], True)

# %%
snid.deleteSN(dataset0, 'sn04aw_bsnip')

# %%
snid.deleteSN(dataset5, 'sn2006jc')
snid.deleteSN(dataset5, 'sn04aw_bsnip')

# %%
snid.deleteSN(dataset10, 'sn2005la')
snid.deleteSN(dataset10, 'sn2006jc')
snid.deleteSN(dataset10, 'sn04aw_bsnip')

# %%
snid.deleteSN(dataset15, 'sn2005la')
snid.deleteSN(dataset15, 'sn2006jc')
snid.deleteSN(dataset15, 'sn04aw_bsnip')

# %%
#snid.deleteSN(dataset20, 'sn2005la')
#snid.deleteSN(dataset20, 'sn2006jc')
#snid.deleteSN(dataset20, 'sn04aw_bsnip')

# %%
#snid.deleteSN(dataset25, 'sn2005la')
#snid.deleteSN(dataset25, 'sn04aw_bsnip')

# %%
snidPCA0 = SNePCA.SNePCA(dataset0, -5, 5)
snidPCA5 = SNePCA.SNePCA(dataset5, 0, 10)
snidPCA10 = SNePCA.SNePCA(dataset10, 5, 15)
snidPCA15 = SNePCA.SNePCA(dataset15, 10, 20)

#snidPCA20 = SNePCA.SNePCA(dataset20, 10, 20)
#snidPCA25 = SNePCA.SNePCA(dataset25, 10, 20)

# %%
snidPCA0.snidPCA()
snidPCA5.snidPCA()
snidPCA10.snidPCA()
snidPCA15.snidPCA()

#snidPCA20.snidPCA()
#snidPCA25.snidPCA()

# %%
snidPCA10.evecs[0] = -snidPCA10.evecs[0]
snidPCA10.evecs[2] = -snidPCA10.evecs[2]

# %%
snidPCA0.calcPCACoeffs()
snidPCA5.calcPCACoeffs()
snidPCA10.calcPCACoeffs()
snidPCA15.calcPCACoeffs()

#snidPCA20.calcPCACoeffs()
#snidPCA25.calcPCACoeffs()

# %%
print snidPCA0.pcaCoeffMatrix.shape
print snidPCA5.pcaCoeffMatrix.shape
print snidPCA10.pcaCoeffMatrix.shape
print snidPCA15.pcaCoeffMatrix.shape

#print snidPCA20.pcaCoeffMatrix.shape
#print snidPCA25.pcaCoeffMatrix.shape
# Out:
# (85, 85)
# (71, 71)
# (69, 69)
# (60, 60)

# %% [markdown]
# # Best 2D Marginalization

# %%
f, highscore, pcax, pcay = snidPCA0.cornerplotPCA(ncomp=5, figsize=(25,20), svm=True, ncv=30)
print "Best pcax, pcay: (%d,%d)"%(pcax, pcay)
print "score = ",highscore
f
# Out:
# 6
# 11
# 12
# 16
# 17
# 18
# 21
# 22
# 23
# 24
# Best pcax, pcay: (3,4)
# score =  0.6910256410256409

# %%
plt.subplot?

# %% [markdown]
# # Eigenspectra

# %%
f, axs = plt.subplots(5,1,figsize=(10,20))

# %%
for i in range(5):
    ax = axs[i]
    ax.set_title('PCA%d Eigenspectra'%(i+1))
    ax.set_xlim((3800,7700))
    ax.set_yticks([])
    ax.plot(snidPCA0.wavelengths,snidPCA0.evecs[i]+2-0,'r',label='phase 0')
    ax.plot(snidPCA0.wavelengths,snidPCA5.evecs[i]+2-.5,'b',label='phase 5')
    ax.plot(snidPCA0.wavelengths,snidPCA10.evecs[i]+2-1,'c',label='phase 10')
    ax.plot(snidPCA0.wavelengths,snidPCA15.evecs[i]+2-1.5,'g',label='phase 15')
    
    ax.plot(snidPCA20.wavelengths,snidPCA20.evecs[i]+2-2,'k',label='phase 20')
    ax.plot(snidPCA25.wavelengths,snidPCA25.evecs[i]+2-2.5,'y',label='phase 25')
    
    ax.legend()

# %%
f

# %%
f.savefig('SNePCAplots/4phase_eig.png')

# %% [markdown]
# # Classification

# %%
f_all, axs = plt.subplots(2,2,figsize=(35,30),gridspec_kw={'wspace':.1,'hspace':.15})

# %%
f_all.axes

# %%
svmsc=[]
f_all,svmsc=snidPCA0.pcaPlot(3,4,(10,7),purity=True, std_rad=1.0, svm=True, count=30, fig=f_all, ax=f_all.axes[0],ncv=50)
#ax = f.gca()

for i in range(30):
    f_all,svmsc=snidPCA0.pcaPlot(3,4,(10,7),purity=True, std_rad=1.0, svm=True, fig=f_all, ax=f_all.axes[0], count=30, svmsc=svmsc, ncv=50)
    #ax = f.gca()
    
#f_all.axes[0].set_title("Phase 0 $\pm$ 5",fontsize=40)
# Out:
# centroid [1.39385686 0.53865981]
# mean dist from centroid:  [0.56550934 0.7427626 ]
# std dist from centroid:  [0.59693187 0.56129049]
# purity rad all components:  [1.1624412 1.3040531]
# ellipse condition:  [0.01105359 2.2144123  1.37027685 3.28757074 2.5288711  2.33881381
#  0.49595097 7.11142509 0.38842703 1.73404971 2.11558759 2.77749078
#  3.19363863 1.30345697 6.88245882 0.15435956 2.08484648 0.74959662
#  0.63826467 2.27822003 1.54923582 1.6487683  2.41797994 2.09063096
#  1.80813861 4.35660829 2.55903261 1.86310843 4.54616879 0.37421458
#  0.67718597 2.12896021 2.08997799 2.88053635 0.87991976 2.82503754
#  2.65486253 1.12221914 1.69563932 2.32201209 0.25034856 2.74802616
#  1.4640808  2.99126356 2.82249808 2.53451707 1.77098488 1.67314372
#  2.23913988 2.11308728 9.7766317  2.30799958 2.29214559 2.2637253
#  3.15738609 1.05416576 2.10698098 0.33789267 1.46732661 1.97594905
#  1.92562947 3.67882444 2.61743507 1.60967936 2.89973863 2.38671239
# ...

# %%
svmsc=[]
f_all,svmsc=snidPCA5.pcaPlot(1,3,(10,7),purity=True, std_rad=1.0, svm=True, count=30, fig=f_all, ax=f_all.axes[1], ncv=50)
#ax = f.gca()

for i in range(30):
    f_all,svmsc=snidPCA5.pcaPlot(1,3,(10,7),purity=True, std_rad=1.0, svm=True, fig=f_all, ax=f_all.axes[1], count=30, svmsc=svmsc, ncv=50)
    #ax = f.gca()
    
#f_all.axes[1].set_title("Phase 5 $\pm$ 5",fontsize=40)
# Out:
# centroid [ 2.84138178 -0.25478509]
# mean dist from centroid:  [1.01044797 0.75847806]
# std dist from centroid:  [0.92310162 0.56619175]
# purity rad all components:  [1.93354959 1.32466982]
# ellipse condition:  [2.44974952e+00 1.47251400e+00 4.12908999e-01 1.85043550e+00
#  1.85886564e+00 2.38410770e-01 1.73092291e-01 1.12832160e-01
#  9.83842986e-01 4.21953023e-01 5.64544546e-01 1.97040267e+00
#  8.05344145e-01 5.77804585e-01 4.11812701e-01 4.34339866e-01
#  2.61514308e+00 3.66991973e+00 2.74661411e+00 1.19032037e+00
#  7.42437954e-01 3.02312876e+00 9.99812994e-01 1.71469039e-01
#  2.79207668e-01 7.84634458e-01 1.63427150e+00 2.10134135e-01
#  4.53335069e-04 4.41594856e-01 4.84997314e-01 3.78281740e+00
#  5.81593792e-01 2.37865606e-01 3.37339816e+00 3.84286988e+00
#  2.45713995e+00 2.24177596e+00 1.86788733e+00 9.91104692e-01
#  1.82105494e+00 2.65615421e+00 3.77921448e+00 1.18953513e+00
#  2.32166921e+00 5.60730017e-01 2.98844585e+00 5.44979537e-01
# ...

# %%
svmsc=[]
f_all,svmsc=snidPCA10.pcaPlot(1,3,(10,7),purity=True, std_rad=1.0, svm=True, count=30, fig=f_all, ax=f_all.axes[2],ncv=50)
#ax = f.gca()

for i in range(30):
    f_all,svmsc=snidPCA10.pcaPlot(1,3,(10,7),purity=True, std_rad=1.0, svm=True, fig=f_all, ax=f_all.axes[2], count=30, svmsc=svmsc,ncv=50)
    #ax = f.gca()
    
#f_all.axes[2].set_title("Phase 10 $\pm$ 5",fontsize=40)
# Out:
# centroid [ 2.95256694 -1.24773924]
# mean dist from centroid:  [1.10471895 1.0020542 ]
# std dist from centroid:  [0.88346546 0.70502954]
# purity rad all components:  [1.98818441 1.70708374]
# ellipse condition:  [3.08537800e+00 8.17768799e-01 3.52502121e+00 2.49201133e+00
#  2.69296754e+00 4.22054596e-01 1.47652027e+00 2.15881650e+00
#  2.13011079e+00 5.57856604e-02 6.69731077e-01 2.70484063e-02
#  8.38040504e-01 9.62200725e-01 9.86981317e-01 1.77955124e+00
#  8.31705589e-01 1.16928460e+00 7.22358556e-01 4.31965076e-01
#  1.74211706e+00 3.25064566e+00 2.98360568e+00 2.61671505e-01
#  9.28494647e-01 2.53375231e+00 1.96255276e+00 4.14832526e-01
#  1.12763376e-04 1.73840498e+00 2.09488416e+00 1.01177883e+00
#  5.59762095e-01 7.45479400e-01 3.48459325e-01 1.07712280e+00
#  4.75283609e+00 4.43181380e-01 2.30838678e+00 3.60494931e+00
#  2.31944831e+00 1.42319068e+00 2.63901101e+00 1.06881800e+00
#  2.29402294e+00 1.60239651e+00 3.05091010e+00 1.45659323e+00
# ...

# %%
svmsc=[]
f_all,svmsc=snidPCA15.pcaPlot(1,3,(10,7),purity=True, std_rad=1.0, svm=True, count=30, fig=f_all, ax=f_all.axes[3],ncv=50)
#ax = f.gca()

for i in range(30):
    f_all,svmsc=snidPCA15.pcaPlot(1,3,(10,7),purity=True, std_rad=1.0, svm=True, fig=f_all, ax=f_all.axes[3], count=30, svmsc=svmsc,ncv=50)
    #ax = f.gca()
    
#f_all.axes[3].set_title("Phase 15 $\pm$ 5",fontsize=40)
# Out:
# centroid [ 3.42492477 -0.68830377]
# mean dist from centroid:  [1.044934   0.89174728]
# std dist from centroid:  [0.88570381 0.55028091]
# purity rad all components:  [1.93063781 1.44202819]
# ellipse condition:  [2.29497215 0.42368313 0.25357155 3.55408378 2.0109188  4.69708743
#  3.12746717 0.18174113 0.3411402  2.69914287 1.84676093 0.26893794
#  0.30788059 0.74643185 0.9045985  3.98269032 3.62053251 4.11145286
#  0.38366337 5.16804526 3.44302274 0.72042899 0.89943863 2.7675717
#  1.31656118 1.09749912 1.55125242 6.83676878 0.44071869 1.6757123
#  1.02200793 1.78849309 1.515908   0.94052605 2.72195458 4.36335613
#  2.8954909  0.91658635 3.94104024 2.34695229 1.88137184 2.45489353
#  6.09952662 2.85570967 0.24207447 3.74128457 2.19730041 0.32498743
#  2.23961356 1.30147867 0.81186544 3.19757518 0.52868116 0.28365437
#  3.76569102 1.7966456  1.17556986 3.41233051 1.79133149 3.22735596]
# IIb
# purity radius:  [1.93063781 1.44202819]
# ...

# %%
svmsc=[]
f_all,svmsc=snidPCA20.pcaPlot(1,3,(10,7),purity=True, std_rad=1.0, svm=True, count=30, fig=f_all, ax=f_all.axes[4],ncv=50)
#ax = f.gca()

for i in range(30):
    f_all,svmsc=snidPCA20.pcaPlot(1,3,(10,7),purity=True, std_rad=1.0, svm=True, fig=f_all, ax=f_all.axes[4], count=30, svmsc=svmsc,ncv=50)
    #ax = f.gca()
    
f_all.axes[4].set_title("Phase 20 $\pm$ 5",fontsize=40)
# Out:
# centroid [ 3.42936895 -0.79883647]
# mean dist from centroid:  [1.18041188 0.99344201]
# std dist from centroid:  [0.6230469  0.55691157]
# purity rad all components:  [1.80345879 1.55035358]
# ellipse condition:  [0.19938055 4.10995431 1.24272659 4.59111859 0.44485027 1.419205
#  3.61001007 0.68392912 0.07315715 1.34111055 5.56556559 4.4707979
#  1.00697086 5.7228658  0.4162938  0.59002753 1.78495149 1.31805296
#  0.20008086 0.7393621  6.82240576 1.57062104 1.31806951 2.31516033
#  4.23710989 2.5882836  4.76568769 2.18985974 0.32034653 2.94074203
#  4.52911892 4.09831378 0.69856537 3.68639259 0.5465314  0.68652144
#  1.37463004 2.44723327 0.6718568  4.40712745 2.64225096 4.30008803
#  1.50095969 4.06464282]
# IIb
# purity radius:  [1.80345879 1.55035358]
# # of SNe within purity ellipse for type IIb:  13
# # of correct SNe IIb:  5
# centroid [3.33012926 0.78258194]
# mean dist from centroid:  [1.13299844 0.88759203]
# std dist from centroid:  [0.804597   0.59727283]
# ...

# %%
svmsc=[]
f_all,svmsc=snidPCA25.pcaPlot(1,3,(10,7),purity=True, std_rad=1.0, svm=True, count=30, fig=f_all, ax=f_all.axes[5],ncv=50)
#ax = f.gca()

for i in range(30):
    f_all,svmsc=snidPCA25.pcaPlot(1,3,(10,7),purity=True, std_rad=1.0, svm=True, fig=f_all, ax=f_all.axes[5], count=30, svmsc=svmsc,ncv=50)
    #ax = f.gca()
    
f_all.axes[5].set_title("Phase 20 $\pm$ 5",fontsize=40)
# Out:
# centroid [3.54686578 0.91579647]
# mean dist from centroid:  [1.14805412 0.99627756]
# std dist from centroid:  [0.5886088  0.62718083]
# purity rad all components:  [1.73666291 1.62345839]
# ellipse condition:  [0.68502198 6.18769321 1.53117666 0.82037219 3.44777167 0.57790895
#  1.03607667 0.72679577 6.13157854 5.15420129 4.16251645 1.77532199
#  8.21162791 0.8597911  2.04966765 2.08781005 2.90251648 2.1249748
#  3.41196912 1.42965895 2.18460286 1.04105216 5.05643902 4.93656533
#  4.09520565 2.38010646 0.88204875 3.39911988 2.6270579  1.26329739
#  1.70065294 1.92972984 1.08048486 0.67606994 3.13702342 1.88904389
#  1.3525609  0.43877526]
# IIb
# purity radius:  [1.73666291 1.62345839]
# # of SNe within purity ellipse for type IIb:  8
# # of correct SNe IIb:  4
# centroid [ 2.60147493 -0.47167834]
# mean dist from centroid:  [1.09538133 0.36828966]
# std dist from centroid:  [0.54885227 0.30668949]
# purity rad all components:  [1.64423359 0.67497915]
# ...

# %%
f_all.axes[0].text(-2.0,3.25,'Phase 0$\pm$5',fontsize=50)
# Out:
# Text(-2,3.25,'Phase 0$\\pm$5')

# %%
ax = f_all.axes[0]

# %%
l = ax.get_legend()

# %%
t = l.get_title()
t.set_fontsize(30)

# %%
ax.set_xlim((-2.5,3))
ax.set_ylim((-2,4))
# Out:
# (-2, 4)

# %%
ax.set_ylabel('PCA4',fontsize=30)
#ax.set_yticks(np.arange(-2,4,1))
ax.set_yticklabels([])
ax.tick_params(axis='y',which='major', length=20,direction='inout')
ax.tick_params(axis='y',which='minor', length=10,direction='inout')

# %%
for i,ax in enumerate(f_all.axes):
    l = ax.get_legend()
    t = l.get_title()
    t.set_fontsize(30)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(axis='both',which='major', length=20,direction='inout')
    ax.tick_params(axis='both',which='minor', length=10,direction='inout')
    if i==0:
        xmin = -2.1
        xmax = 2.6
        ymin = -1.8
        ymax = 3.6
        ax.set_xlim((xmin, xmax))
        ax.set_ylim((ymin,ymax))
        ax.text(xmin + .5,ymax - .5,'$t_{V_{max}} = 0 \pm 5$ days',fontsize=50)
        ax.set_ylabel('PCA Comp 4', fontsize=50)
        ax.set_xlabel('PCA Comp 3', fontsize=50)
    elif i==1:
        xmin = -1.25
        xmax = 5.4
        ymin = -1.8
        ymax = 2.6
        ax.set_xlim((xmin, xmax))
        ax.set_ylim((ymin,ymax))
        ax.text(xmin + .5,ymax - .5,'$t_{V_{max}} = 5 \pm 5$ days',fontsize=50)
        ax.set_ylabel('PCA Comp 3', fontsize=50)
        ax.set_xlabel('PCA Comp 1', fontsize=50)
    elif i==2:
        xmin = -1.25
        xmax = 5.4
        ymin = -3.4
        ymax = 2.7
        ax.set_xlim((xmin, xmax))
        ax.set_ylim((ymin,ymax))
        ax.text(xmin + .5,ymax - .5,'$t_{V_{max}} = 10 \pm 5$ days',fontsize=50)
        ax.set_ylabel('PCA Comp 3', fontsize=50)
        ax.set_xlabel('PCA Comp 1', fontsize=50)
    else:
        xmin = -1.25
        xmax = 5.4
        ymin = -1.8
        ymax = 3.0
        ax.set_xlim((xmin, xmax))
        ax.set_ylim((ymin,ymax))
        ax.text(xmin + .5,ymax - .5,'$t_{V_{max}} = 15 \pm 5$ days',fontsize=50)
        ax.set_ylabel('PCA Comp 3', fontsize=50)
        ax.set_xlabel('PCA Comp 1', fontsize=50)

# %%
f_all

# %%
f_all.savefig('SNePCAplots/4phase_marg_final_colors.png',bbox_inches='tight')

# %% [markdown]
# # 2phase Plot

# %%
f_all, axs = plt.subplots(1,2,figsize=(35,15),gridspec_kw={'wspace':.1,'hspace':.15})

# %%
svmsc=[]
f_all,svmsc=snidPCA0.pcaPlot(3,4,(10,7),purity=True, std_rad=1.0, svm=True, count=30, fig=f_all, ax=f_all.axes[0],ncv=50)
#ax = f.gca()

for i in range(30):
    f_all,svmsc=snidPCA0.pcaPlot(3,4,(10,7),purity=True, std_rad=1.0, svm=True, fig=f_all, ax=f_all.axes[0], count=30, svmsc=svmsc, ncv=50)
    #ax = f.gca()
    
#f_all.axes[0].set_title("Phase 0 $\pm$ 5",fontsize=40)
# Out:
# centroid [1.39385686 0.53865981]
# mean dist from centroid:  [0.56550934 0.7427626 ]
# std dist from centroid:  [0.59693187 0.56129049]
# purity rad all components:  [1.1624412 1.3040531]
# ellipse condition:  [0.01105359 2.2144123  1.37027685 3.28757074 2.5288711  2.33881381
#  0.49595097 7.11142509 0.38842703 1.73404971 2.11558759 2.77749078
#  3.19363863 1.30345697 6.88245882 0.15435956 2.08484648 0.74959662
#  0.63826467 2.27822003 1.54923582 1.6487683  2.41797994 2.09063096
#  1.80813861 4.35660829 2.55903261 1.86310843 4.54616879 0.37421458
#  0.67718597 2.12896021 2.08997799 2.88053635 0.87991976 2.82503754
#  2.65486253 1.12221914 1.69563932 2.32201209 0.25034856 2.74802616
#  1.4640808  2.99126356 2.82249808 2.53451707 1.77098488 1.67314372
#  2.23913988 2.11308728 9.7766317  2.30799958 2.29214559 2.2637253
#  3.15738609 1.05416576 2.10698098 0.33789267 1.46732661 1.97594905
#  1.92562947 3.67882444 2.61743507 1.60967936 2.89973863 2.38671239
# ...

# %%
svmsc=[]
f_all,svmsc=snidPCA0.pcaPlot(1,4,(10,7),purity=True, std_rad=1.0, svm=True, count=30, fig=f_all, ax=f_all.axes[1], ncv=50)
#ax = f.gca()

for i in range(30):
    f_all,svmsc=snidPCA0.pcaPlot(1,4,(10,7),purity=True, std_rad=1.0, svm=True, fig=f_all, ax=f_all.axes[1], count=30, svmsc=svmsc, ncv=50)
    #ax = f.gca()
    
#f_all.axes[1].set_title("Phase 5 $\pm$ 5",fontsize=40)
# Out:
# centroid [2.12628769 0.53865981]
# mean dist from centroid:  [0.80858781 0.7427626 ]
# std dist from centroid:  [0.58422231 0.56129049]
# purity rad all components:  [1.39281012 1.3040531 ]
# ellipse condition:  [0.10062156 1.85592006 1.35861678 1.58350401 1.66206246 0.29006068
#  0.18237795 2.72637698 0.44943958 0.57958817 1.81476447 1.45837655
#  0.24024807 0.13913718 3.03016019 0.38777615 1.191166   0.7601913
#  1.15572884 0.23451755 1.6409922  2.92321058 4.0738928  4.55081397
#  3.1242967  3.10762421 0.91905798 1.84828138 1.51868331 0.48194805
#  0.12193686 1.04257938 1.04400966 0.36060889 1.41191744 0.10812537
#  2.66173432 0.513739   0.23118969 0.29146548 1.1743046  2.93988029
#  3.43242437 0.19530968 0.04111285 0.79947123 2.87996213 4.67924823
#  2.31107279 2.21863975 1.55748254 1.54275354 3.03128891 3.16640549
#  2.41016789 4.76538833 0.85747776 0.30547945 3.49897123 0.34132959
#  1.2726209  1.72878103 0.6638501  3.41001072 2.5196958  1.53289309
# ...

# %%
for i,ax in enumerate(f_all.axes):
    l = ax.get_legend()
    t = l.get_title()
    t.set_fontsize(30)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(axis='both',which='major', length=20,direction='inout')
    ax.tick_params(axis='both',which='minor', length=10,direction='inout')
    if i==0:
        xmin = -2.1
        xmax = 2.6
        ymin = -1.8
        ymax = 3.6
        ax.set_xlim((xmin, xmax))
        ax.set_ylim((ymin,ymax))
        ax.text(xmin + .5,ymax - .5,'$t_{V_{max}} = 0 \pm 5$ days',fontsize=50)
        ax.set_ylabel('PCA Comp 4', fontsize=50)
        ax.set_xlabel('PCA Comp 3', fontsize=50)
    elif i==1:
        xmin = -1.25
        xmax = 5.4
        ymin = -1.8
        ymax = 2.6
        ax.set_xlim((xmin, xmax))
        ax.set_ylim((ymin,ymax))
        ax.text(xmin + .5,ymax - .5,'$t_{V_{max}} = 0 \pm 5$ days',fontsize=50)
        ax.set_ylabel('PCA Comp 4', fontsize=50)
        ax.set_xlabel('PCA Comp 1', fontsize=50)
    elif i==2:
        xmin = -1.25
        xmax = 5.4
        ymin = -3.4
        ymax = 2.7
        ax.set_xlim((xmin, xmax))
        ax.set_ylim((ymin,ymax))
        ax.text(xmin + .5,ymax - .5,'$t_{V_{max}} = 10 \pm 5$ days',fontsize=50)
        ax.set_ylabel('PCA Comp 3', fontsize=50)
        ax.set_xlabel('PCA Comp 1', fontsize=50)
    else:
        xmin = -1.25
        xmax = 5.4
        ymin = -1.8
        ymax = 3.0
        ax.set_xlim((xmin, xmax))
        ax.set_ylim((ymin,ymax))
        ax.text(xmin + .5,ymax - .5,'$t_{V_{max}} = 15 \pm 5$ days',fontsize=50)
        ax.set_ylabel('PCA Comp 3', fontsize=50)
        ax.set_xlabel('PCA Comp 1', fontsize=50)

# %%
f_all

# %%
f_all.savefig('SNePCAplots/2phase_marg_final_colors.png',bbox_inches='tight')

# %%
IIbmsk, Ibmsk, Icmsk, IcBLmsk=snidPCA0.getSNeTypeMasks()

# %%
plt.clf()
x=snidPCA0.pcaCoeffMatrix[:,2][IIbmsk]
y=snidPCA0.pcaCoeffMatrix[:,3][IIbmsk]
xmean=np.mean(x)
xd=np.abs(x-xmean)
print xmean
print np.std(xd)
plt.scatter(x, y)
plt.ylim((-3.5,4))
plt.xlim((-4,4))
plt.show()
# Out:
# 1.393856858210044
# 0.5969318677024567

# %%
f_all.savefig('SNePCAplots/4phase_marg_final_colors.png',bbox_inches='tight')

# %%
plt.clf()
plt.plot([1,2],[1,2],'r',label='test')
plt.plot([4,5],[4,5],'b',label='test2')
plt.legend(ncol=2)
plt.show()

# %%
reload(SNePCA)
# Out:
# <module 'SNePCA' from 'SNePCA.py'>

# %%
import seaborn as sns
sns.set_color_codes('colorblind')
import matplotlib.pyplot as plt

import matplotlib.patches as mpatches
import matplotlib.transforms as transforms
import matplotlib.gridspec as gridspec
from matplotlib.colors import LinearSegmentedColormap
import numpy as np

# %%
plt.clf()
plt.scatter([1,2],[3,4],c=(1,0,0),s=400)
plt.show()

# %%
plt.clf()
x = np.arange(0, np.pi, 0.1)
y = np.arange(0, 2 * np.pi, 0.1)
X, Y = np.meshgrid(x, y)
Z = np.cos(X) * np.sin(Y) * 10

colors = [(0, 1, 0.0), (1, 0, 0), (0, 0, 1)]  # R -> G -> B
n_bins = [3, 6, 10, 100]  # Discretizes the interpolation into bins
cmap_name = 'my_list'
fig, axs = plt.subplots(2, 2, figsize=(6, 9))
fig.subplots_adjust(left=0.02, bottom=0.06, right=0.95, top=0.94, wspace=0.05)
for n_bin, ax in zip(n_bins, axs.ravel()):
    # Create the colormap
    cm = LinearSegmentedColormap.from_list(
        cmap_name, colors, N=n_bin)
    # Fewer bins will result in "coarser" colomap interpolation
    im = ax.imshow(Z, interpolation='nearest', origin='lower', cmap=cm)
    ax.set_title("N bins: %s" % n_bin)
    fig.colorbar(im, ax=ax)
plt.show()

# %%
plt.clf()
plt.scatter([1,2],[2,3],s=50)
plt.show()
